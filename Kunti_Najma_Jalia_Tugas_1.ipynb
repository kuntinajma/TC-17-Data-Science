# %% [markdown]
# <a href="https://colab.research.google.com/github/kuntinajma/TC-17-Data-Science/blob/main/Kunti_Najma_Jalia_Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('diabetes_null.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0            4.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10     11.0           76.0           48.0     18.0  32.9
# 764            2    122.0            7.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0            6.0            NaN      NaN   3.1
# 767            1     93.0            7.0           31.0      NaN   3.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627    5        1
# ...

# %%
df.groupby('Pregnancies').max()
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 0              198.0           96.0           63.0    478.0  67.1
# 1              199.0          122.0           52.0    846.0  55.0
# 2              197.0           96.0           99.0    543.0  45.5
# 3              193.0           92.0           49.0    474.0  57.3
# 4              197.0           92.0           47.0    744.0  48.3
# 5              189.0           98.0           44.0    545.0  52.9
# 6              195.0           96.0           45.0    326.0  46.2
# 7              196.0           95.0           49.0    392.0  46.7
# 8              197.0           96.0           46.0    495.0  47.9
# 9              184.0           94.0           46.0    175.0  45.4
# 10             179.0           98.0           48.0    237.0  45.6
# 11             155.0           94.0           37.0    146.0  52.3
# 12             151.0           85.0           43.0    325.0  41.8
# ...

# %%
df_2 = df.iloc[:2,0:3]
df_2
# Out:
#    Pregnancies  Glucose  BloodPressure
# 0            6    148.0           72.0
# 1            1     85.0           66.0

# %%
df_3 = df.rename(columns = {'population' : 'penduduk','total_bedrooms':'jumlah kamar'})
df_3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0            4.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10     11.0           76.0           48.0     18.0  32.9
# 764            2    122.0            7.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0            6.0            NaN      NaN   3.1
# 767            1     93.0            7.0           31.0      NaN   3.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627    5        1
# ...

# %%
df_3.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-22fec8d38c61> in <cell line: 1>()
# ----> 1 df_3.groupby()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9179
#    9180         if level is None and by is None:
# -> 9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
#    9183         return DataFrameGroupBy(
#
# TypeError: You have to supply one of 'by' and 'level'

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
# ## 1. Remove Null Value

# %%
df_clean = df.dropna()

print(df_clean)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0            4.0           35.0    168.0  43.1
# 6              3     78.0            5.0           32.0     88.0  31.0
# 8              2    197.0            7.0           45.0    543.0   3.5
# 13             1    189.0            6.0           23.0    846.0   3.1
# ..           ...      ...            ...            ...      ...   ...
# 753            0    181.0           88.0           44.0     51.0  43.3
# 755            1    128.0           88.0           39.0     11.0  36.5
# 760            2     88.0           58.0           26.0     16.0  28.4
# 763           10     11.0           76.0           48.0     18.0  32.9
# 765            5    121.0           72.0           23.0    112.0  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 3                       0.167   21        0
# ...

# %% [markdown]
# ## 2. Fill Null Value with Mean

# %%
df_filled_mean = df.fillna(df.mean())


print(df_filled_mean)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0              6    148.0           72.0      35.000000  105.659898  33.6
# 1              1     85.0           66.0      29.000000  105.659898  26.6
# 2              8    183.0           64.0      25.876155  105.659898  23.3
# 3              1     89.0           66.0      23.000000   94.000000  28.1
# 4              0    137.0            4.0      35.000000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763           10     11.0           76.0      48.000000   18.000000  32.9
# 764            2    122.0            7.0      27.000000  105.659898  36.8
# 765            5    121.0           72.0      23.000000  112.000000  26.2
# 766            1    126.0            6.0      25.876155  105.659898   3.1
# 767            1     93.0            7.0      31.000000  105.659898   3.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# ## 3. Fill Null Value with Median

# %%
df_filled_median = df.fillna(df.median())


print(df_filled_median)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0     71.0  33.6
# 1              1     85.0           66.0           29.0     71.0  26.6
# 2              8    183.0           64.0           27.0     71.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0            4.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10     11.0           76.0           48.0     18.0  32.9
# 764            2    122.0            7.0           27.0     71.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0            6.0           27.0     71.0   3.1
# 767            1     93.0            7.0           31.0     71.0   3.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627    5        1
# ...

# %% [markdown]
# ## 4. Fill Null Value with Minimum Value

# %%
df_filled_min = df.fillna(df.min())


print(df_filled_min)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      1.0  33.6
# 1              1     85.0           66.0           29.0      1.0  26.6
# 2              8    183.0           64.0            1.0      1.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0            4.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10     11.0           76.0           48.0     18.0  32.9
# 764            2    122.0            7.0           27.0      1.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0            6.0            1.0      1.0   3.1
# 767            1     93.0            7.0           31.0      1.0   3.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627    5        1
# ...
